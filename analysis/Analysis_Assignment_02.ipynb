# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    'Gender': ['Female', 'Male', 'Male', 'Male', 'Female', 'Male'],  # Qualitative
    'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'Finance'],    # Qualitative
    'Age': [25, 30, 45, 28, 35, 40],                                # Quantitative
    'Salary': [40000, 55000, 75000, 50000, 62000, 68000]            # Quantitative
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Name  Gender Department  Age  Salary
# 0    Alice  Female         HR   25   40000
# 1      Bob    Male         IT   30   55000
# 2  Charlie    Male    Finance   45   75000
# 3    David    Male         IT   28   50000
# 4      Eva  Female         HR   35   62000

# %%
# --- QUALITATIVE ANALYSIS ---
print("Qualitative Analysis:")
print(df['Gender'].value_counts())      # Frequency of categories
print(df['Department'].value_counts())  # Frequency of departments

# Bar chart for Gender distribution
df['Gender'].value_counts().plot(kind='bar', color=['pink', 'lightblue'])
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# Qualitative Analysis:
# Gender
# Male      4
# Female    2
# Name: count, dtype: int64
# Department
# HR         2
# IT         2
# Finance    2
# Name: count, dtype: int64

# %%
# --- QUANTITATIVE ANALYSIS ---
print("\nQuantitative Analysis:")
print(df[['Age', 'Salary']].describe())  # Summary statistics

# Histogram for Age
df['Age'].plot(kind='hist', bins=5, color='skyblue', edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Scatter plot: Age vs Salary
plt.scatter(df['Age'], df['Salary'], color='green')
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()
# Out:
# Quantitative Analysis:
#              Age        Salary
# count   6.000000      6.000000
# mean   33.833333  58333.333333
# std     7.626707  12659.647178
# min    25.000000  40000.000000
# 25%    28.500000  51250.000000
# 50%    32.500000  58500.000000
# 75%    38.750000  66500.000000
# max    45.000000  75000.000000
